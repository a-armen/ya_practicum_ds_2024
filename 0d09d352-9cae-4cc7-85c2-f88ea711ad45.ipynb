# %% [markdown]
# <div class="alert alert-success" style="border-color: green; border-radius: 5px">
#     <p><u><b>✅ КОММЕНТАРИЙ МЕНТОРА</b></u></p>
# Здравствуй Армен!<br>
# Это Николай. И нам повезло - мы делаем интереснейший проект!<br>
# Далее, я постарюсь прокомментировать сделанные шаги.<br>
# Вперёд!
#
# Чтобы меньше "мусорить эфир" и чтобы максимально наглядно отделяться от основного кода, есть предложение условиться в некоторых обозначениях:<br /> <br />
# <div class="alert alert-success" style="border-color: green; border-radius: 5px">
#     <p><u><b>✅ КОММЕНТАРИЙ МЕНТОРА</b></u></p>
#     <p>Всё хорошо.</p>
# </div>
#
# <div class="alert alert-warning" style="border-color: darkorange; border-radius: 5px">
#     <p><u><b>⚠️ КОММЕНТАРИЙ МЕНТОРА</b></u></p>
#     <p>Обрати внимание, есть потенциал</p>
# </div>
#
# <div class="alert alert-danger" style="border-color: darkred; border-radius: 5px">
#     <p><u><b>❌ КОММЕНТАРИЙ МЕНТОРА</b></u></p>
#     <p>Нужно ещё раз глянуть</p>
# </div>
#
# <font color='green'>Как и всегда в спринтах - ставлю своей целью максимально помочь. Поэтому, все мои комментарии - это только способ передать свой опыт для помощи в твоих достижениях.

# %% [markdown]
# # Оптимизация производственных расходов металлургического комбината "Стальная птица" при потребление электроэнергии на этапе обработки стали.

# %% [markdown]
# **Описание проекта**
#
# *Чтобы оптимизировать производственные расходы, металлургический комбинат «Стальная птица» решил уменьшить потребление электроэнергии на этапе обработки стали. Для этого комбинату нужно контролировать температуру сплава. Наша задача — построить модель, которая будет её предсказывать.
# Заказчик хочет использовать разработанную модель для имитации технологического процесса.*
#
#
# **Описание этапа обработки**
#
# *Сталь обрабатывают в металлическом ковше вместимостью около 100 тонн. Чтобы ковш выдерживал высокие температуры, изнутри его облицовывают огнеупорным кирпичом. Расплавленную сталь заливают в ковш и подогревают до нужной температуры графитовыми электродами. Они установлены в крышке ковша.*
#
# *Из сплава выводится сера (этот процесс — десульфурация), добавлением примесей корректируется химический состав и отбираются пробы. Сталь легируют — изменяют её состав — подавая куски сплава из бункера для сыпучих материалов или проволоку через специальный трайб-аппарат (от англ. tribe — «масса»).*
#
# *Перед тем как первый раз ввести легирующие добавки, измеряют температуру стали и производят её химический анализ. Потом температуру на несколько минут повышают, добавляют легирующие материалы и продувают сплав инертным газом. Затем его перемешивают и снова проводят измерения. Такой цикл повторяется до достижения целевого химического состава и оптимальной температуры плавки.*
#
# *Тогда расплавленная сталь отправляется на доводку металла или поступает в машину непрерывной разливки. Оттуда готовый продукт выходит в виде заготовок-слябов (от англ. slab — «плита»).*

# %% [markdown]
# **Описание данных**
#
# Данные состоят из нескольких файлов, полученных из разных источников:
#
# - `data_arc_new.csv` — данные об электродах;
# - `data_bulk_new.csv` — данные о подаче сыпучих материалов (объём);
# - `data_bulk_time_new.csv` — данные о подаче сыпучих материалов (время);
# - `data_gas_new.csv` — данные о продувке сплава газом;
# - `data_temp_new.csv` — результаты измерения температуры;
# - `data_wire_new.csv`— данные о проволочных материалах (объём);
# - `data_wire_time_new.csv` — данные о проволочных материалах (время).
#
# **Файл data_arc_new.csv**
#
# - `key` — номер партии;
# - `Начало нагрева дугой` — время начала нагрева;
# - `Конец нагрева дугой` — время окончания нагрева;
# - `Активная мощность` — значение активной мощности;
# - `Реактивная мощность` — значение реактивной мощности.
#
#
# **Файл data_bulk_new.csv**
# - `key` — номер партии;
# - `Bulk 1 … Bulk 15` — объём подаваемого материала.
#
#
# **Файл data_bulk_time_new.csv**
# - `key` — номер партии;
# - `Bulk 1 … Bulk 15` — время подачи материала.
#
#
# **Файл data_gas_new.csv**
# - `key` — номер партии;
# - `Газ 1` — объём подаваемого газа.
#
#
# **Файл data_temp_new.csv**
# - `key` — номер партии;
# - `Время замера` — время замера;
# - `Температура` — значение температуры.
#
#
# **Файл data_wire_new.csv**
# - `key` — номер партии;
# - `Wire 1 … Wire 9` — объём подаваемых проволочных материалов.
#
#
# **Файл data_wire_time_new.csv**
# - `key` — номер партии;
# - `Wire 1 … Wire 9` — время подачи проволочных материалов.
#
#
#
# *Во всех файлах столбец key содержит номер партии. В файлах может быть несколько строк с одинаковым значением `key`: они соответствуют разным итерациям обработки.*
#
# *Данные также находятся в тренажёре, в папке `/datasets/`.*

# %% [markdown]
# **План работы**
#
# 1. Загрузка данных
# 2. Исследовательский анализ и предобработка данных
# 3. Объединение данных
# 4. Исследовательский анализ и предобработка данных объединённого датафрейма
# 5. Подготовка данных
# 6. Обучение моделей машинного обучения
# 7. Выбор лучшей модели
# 8. Общий вывод и рекомендации заказчику

# %% [markdown]
# <div class="alert alert-success" style="border-color: green; border-radius: 5px">
#     <p><u><b>✅ КОММЕНТАРИЙ МЕНТОРА</b></u></p>
#     <p>ок, это хороший тон - дать описание проблематики.</p>
# </div>

# %%
import pandas as pd
import numpy as np
import re
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error
from lightgbm import LGBMRegressor
from catboost import CatBoostRegressor
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import mean_absolute_error as mae
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler, PolynomialFeatures

import warnings
warnings.filterwarnings('ignore')

# %%
RANDOM_STATE = 11024
TEST_SIZE = 0.25

# %%
server_path_arc_new = '/datasets/data_arc_new.csv'
loc_path_arc_new = 'data_arc_new.csv'

server_path_bulk_new = '/datasets/data_bulk_new.csv'
loc_path_bulk_new = 'data_bulk_new.csv'

server_path_bulk_time_new = '/datasets/data_bulk_time_new.csv'
loc_path_bulk_time_new = 'data_bulk_time_new.csv'

server_path_gas_new = '/datasets/data_gas_new.csv'
loc_path_gas_new = 'data_gas_new.csv'

server_path_temp_new = '/datasets/data_temp_new.csv'
loc_path_temp_new = 'data_temp_new.csv'

server_path_wire_new = '/datasets/data_wire_new.csv'
loc_path_wire_new = 'data_wire_new.csv'

server_path_wire_time_new = '/datasets/data_wire_time_new.csv'
loc_path_wire_time_new = 'data_wire_time_new.csv'

# %% [markdown]
# ## Загрузка данных

# %% [markdown]
# **Загрузите данные и выполните их первичный осмотр.**

# %%
try:
    df_arc_new = pd.read_csv(server_path_arc_new)
    df_bulk_new = pd.read_csv(server_path_bulk_new)
    df_bulk_time_new = pd.read_csv(server_path_bulk_time_new)
    df_gas_new = pd.read_csv(server_path_gas_new)
    df_temp_new = pd.read_csv(server_path_temp_new)
    df_wire_new = pd.read_csv(server_path_wire_new)
    df_wire_time_new = pd.read_csv(server_path_wire_time_new)
    
except:
    df_arc_new = pd.read_csv(loc_path_arc_new)
    df_bulk_new = pd.read_csv(loc_path_bulk_new)
    df_bulk_time_new = pd.read_csv(loc_path_bulk_time_new)
    df_gas_new = pd.read_csv(loc_path_gas_new)
    df_temp_new = pd.read_csv(loc_path_temp_new)
    df_wire_new = pd.read_csv(loc_path_wire_new)
    df_wire_time_new = pd.read_csv(loc_path_wire_time_new)

# %% [markdown]
# <div class="alert alert-success" style="border-color: green; border-radius: 5px">
#     <p><u><b>✅ КОММЕНТАРИЙ МЕНТОРА</b></u></p>
#     <p>данные на базе) отлично</p>
# </div>

# %% [markdown]
# - **Файл data_arc_new.csv**

# %%
df_arc_new.head()
# Out:
#    key Начало нагрева дугой  Конец нагрева дугой  Активная мощность  \
# 0    1  2019-05-03 11:02:14  2019-05-03 11:06:02           0.305130
# 1    1  2019-05-03 11:07:28  2019-05-03 11:10:33           0.765658
# 2    1  2019-05-03 11:11:44  2019-05-03 11:14:36           0.580313
# 3    1  2019-05-03 11:18:14  2019-05-03 11:24:19           0.518496
# 4    1  2019-05-03 11:26:09  2019-05-03 11:28:37           0.867133
#
#    Реактивная мощность
# 0             0.211253
# 1             0.477438
# 2             0.430460
# 3             0.379979
# 4             0.643691

# %%
df_arc_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14876 entries, 0 to 14875
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   key                   14876 non-null  int64
#  1   Начало нагрева дугой  14876 non-null  object
#  2   Конец нагрева дугой   14876 non-null  object
#  3   Активная мощность     14876 non-null  float64
#  4   Реактивная мощность   14876 non-null  float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 581.2+ KB

# %%
df_arc_new.isna().sum()
# Out:
# key                     0
# Начало нагрева дугой    0
# Конец нагрева дугой     0
# Активная мощность       0
# Реактивная мощность     0
# dtype: int64

# %% [markdown]
# 1. Не соответствие типов данных в
#   - Начало нагрева дугой  object (datatime)
#   - Конец нагрева дугой   object (datatime)
#
# 2. Названия столбцов необхлодимо привести к "змеинному стилю".

# %% [markdown]
# <div class="alert alert-success" style="border-color: green; border-radius: 5px">
#     <p><u><b>✅ КОММЕНТАРИЙ МЕНТОРА</b></u></p>
#     <p>первый пошёл))                   ок.</p>
# </div>

# %% [markdown]
# - **Файл data_bulk_new.csv**

# %%
df_bulk_new.head()
# Out:
#    key  Bulk 1  Bulk 2  Bulk 3  Bulk 4  Bulk 5  Bulk 6  Bulk 7  Bulk 8  \
# 0    1     NaN     NaN     NaN    43.0     NaN     NaN     NaN     NaN
# 1    2     NaN     NaN     NaN    73.0     NaN     NaN     NaN     NaN
# 2    3     NaN     NaN     NaN    34.0     NaN     NaN     NaN     NaN
# 3    4     NaN     NaN     NaN    81.0     NaN     NaN     NaN     NaN
# 4    5     NaN     NaN     NaN    78.0     NaN     NaN     NaN     NaN
#
#    Bulk 9  Bulk 10  Bulk 11  Bulk 12  Bulk 13  Bulk 14  Bulk 15
# 0     NaN      NaN      NaN    206.0      NaN    150.0    154.0
# 1     NaN      NaN      NaN    206.0      NaN    149.0    154.0
# 2     NaN      NaN      NaN    205.0      NaN    152.0    153.0
# 3     NaN      NaN      NaN    207.0      NaN    153.0    154.0
# 4     NaN      NaN      NaN    203.0      NaN    151.0    152.0

# %%
df_bulk_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3129 entries, 0 to 3128
# Data columns (total 16 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   key      3129 non-null   int64
#  1   Bulk 1   252 non-null    float64
#  2   Bulk 2   22 non-null     float64
#  3   Bulk 3   1298 non-null   float64
#  4   Bulk 4   1014 non-null   float64
#  5   Bulk 5   77 non-null     float64
#  6   Bulk 6   576 non-null    float64
#  7   Bulk 7   25 non-null     float64
#  8   Bulk 8   1 non-null      float64
#  9   Bulk 9   19 non-null     float64
#  10  Bulk 10  176 non-null    float64
#  11  Bulk 11  177 non-null    float64
#  12  Bulk 12  2450 non-null   float64
#  13  Bulk 13  18 non-null     float64
#  14  Bulk 14  2806 non-null   float64
#  15  Bulk 15  2248 non-null   float64
# dtypes: float64(15), int64(1)
# memory usage: 391.2 KB

# %%
df_bulk_new.isna().sum()
# Out:
# key           0
# Bulk 1     2877
# Bulk 2     3107
# Bulk 3     1831
# Bulk 4     2115
# Bulk 5     3052
# Bulk 6     2553
# Bulk 7     3104
# Bulk 8     3128
# Bulk 9     3110
# Bulk 10    2953
# Bulk 11    2952
# Bulk 12     679
# Bulk 13    3111
# Bulk 14     323
# Bulk 15     881
# dtype: int64

# %% [markdown]
# 1. Большое количество пропусков
# 2. Названия столбцов необхлодимо привести к "змеинному стилю".

# %% [markdown]
# <div class="alert alert-success" style="border-color: green; border-radius: 5px">
#     <p><u><b>✅ КОММЕНТАРИЙ МЕНТОРА</b></u></p>
#     <p>
# ок, идём дальше)
# </p>
# </div>

# %% [markdown]
# - **Файл data_bulk_time_new.csv**

# %%
df_bulk_time_new.head()
# Out:
#    key Bulk 1 Bulk 2 Bulk 3               Bulk 4 Bulk 5 Bulk 6 Bulk 7 Bulk 8  \
# 0    1    NaN    NaN    NaN  2019-05-03 11:28:48    NaN    NaN    NaN    NaN
# 1    2    NaN    NaN    NaN  2019-05-03 11:36:50    NaN    NaN    NaN    NaN
# 2    3    NaN    NaN    NaN  2019-05-03 12:32:39    NaN    NaN    NaN    NaN
# 3    4    NaN    NaN    NaN  2019-05-03 12:43:22    NaN    NaN    NaN    NaN
# 4    5    NaN    NaN    NaN  2019-05-03 13:30:47    NaN    NaN    NaN    NaN
#
#   Bulk 9 Bulk 10 Bulk 11              Bulk 12 Bulk 13              Bulk 14  \
# 0    NaN     NaN     NaN  2019-05-03 11:24:31     NaN  2019-05-03 11:14:50
# 1    NaN     NaN     NaN  2019-05-03 11:53:30     NaN  2019-05-03 11:48:37
# 2    NaN     NaN     NaN  2019-05-03 12:27:13     NaN  2019-05-03 12:21:01
# 3    NaN     NaN     NaN  2019-05-03 12:58:00     NaN  2019-05-03 12:51:11
# 4    NaN     NaN     NaN  2019-05-03 13:30:47     NaN  2019-05-03 13:34:12
#
#                Bulk 15
# 0  2019-05-03 11:10:43
# ...

# %%
df_bulk_time_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3129 entries, 0 to 3128
# Data columns (total 16 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   key      3129 non-null   int64
#  1   Bulk 1   252 non-null    object
#  2   Bulk 2   22 non-null     object
#  3   Bulk 3   1298 non-null   object
#  4   Bulk 4   1014 non-null   object
#  5   Bulk 5   77 non-null     object
#  6   Bulk 6   576 non-null    object
#  7   Bulk 7   25 non-null     object
#  8   Bulk 8   1 non-null      object
#  9   Bulk 9   19 non-null     object
#  10  Bulk 10  176 non-null    object
#  11  Bulk 11  177 non-null    object
#  12  Bulk 12  2450 non-null   object
#  13  Bulk 13  18 non-null     object
#  14  Bulk 14  2806 non-null   object
#  15  Bulk 15  2248 non-null   object
# dtypes: int64(1), object(15)
# memory usage: 391.2+ KB

# %%
df_bulk_time_new.isna().sum()
# Out:
# key           0
# Bulk 1     2877
# Bulk 2     3107
# Bulk 3     1831
# Bulk 4     2115
# Bulk 5     3052
# Bulk 6     2553
# Bulk 7     3104
# Bulk 8     3128
# Bulk 9     3110
# Bulk 10    2953
# Bulk 11    2952
# Bulk 12     679
# Bulk 13    3111
# Bulk 14     323
# Bulk 15     881
# dtype: int64

# %% [markdown]
# 1. Большое количество пропусков
# 2. Названия столбцов необхлодимо привести к "змеинному стилю".
# 3. Не соответствие типов данных в
#     -  Bulk 4  object (datatime)
#     -  Bulk 12 object (datatime)
#     -  Bulk 14 object (datatime)
#     -  Bulk 15 object (datatime)

# %% [markdown]
# - **Файл data_gas_new.csv**

# %%
df_gas_new.head()
# Out:
#    key      Газ 1
# 0    1  29.749986
# 1    2  12.555561
# 2    3  28.554793
# 3    4  18.841219
# 4    5   5.413692

# %%
df_gas_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3239 entries, 0 to 3238
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   key     3239 non-null   int64
#  1   Газ 1   3239 non-null   float64
# dtypes: float64(1), int64(1)
# memory usage: 50.7 KB

# %%
df_gas_new.isna().sum()
# Out:
# key      0
# Газ 1    0
# dtype: int64

# %% [markdown]
# 1. Названия столбцов необхлодимо привести к "змеинному стилю".

# %% [markdown]
# - **Файл data_temp_new.csv**

# %%
df_temp_new.head()
# Out:
#    key         Время замера  Температура
# 0    1  2019-05-03 11:02:04       1571.0
# 1    1  2019-05-03 11:07:18       1604.0
# 2    1  2019-05-03 11:11:34       1618.0
# 3    1  2019-05-03 11:18:04       1601.0
# 4    1  2019-05-03 11:25:59       1606.0

# %%
df_temp_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18092 entries, 0 to 18091
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   key           18092 non-null  int64
#  1   Время замера  18092 non-null  object
#  2   Температура   14665 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 424.2+ KB

# %%
df_temp_new.isna().sum()
# Out:
# key                0
# Время замера       0
# Температура     3427
# dtype: int64

# %% [markdown]
# 1. Имеются пропуски пропусков в столбце `Температура`
# 2. Названия столбцов необхлодимо привести к "змеинному стилю".
# 3. Не соответствие типов данных в `Время замера`  object (datatime)

# %% [markdown]
# - **Файл data_wire_new.csv**

# %%
df_wire_new.head()
# Out:
#    key     Wire 1   Wire 2  Wire 3  Wire 4  Wire 5  Wire 6  Wire 7  Wire 8  \
# 0    1  60.059998      NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1    2  96.052315      NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2    3  91.160157      NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 3    4  89.063515      NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4    5  89.238236  9.11456     NaN     NaN     NaN     NaN     NaN     NaN
#
#    Wire 9
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %%
df_wire_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3081 entries, 0 to 3080
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   key     3081 non-null   int64
#  1   Wire 1  3055 non-null   float64
#  2   Wire 2  1079 non-null   float64
#  3   Wire 3  63 non-null     float64
#  4   Wire 4  14 non-null     float64
#  5   Wire 5  1 non-null      float64
#  6   Wire 6  73 non-null     float64
#  7   Wire 7  11 non-null     float64
#  8   Wire 8  19 non-null     float64
#  9   Wire 9  29 non-null     float64
# dtypes: float64(9), int64(1)
# memory usage: 240.8 KB

# %%
df_wire_new.isna().sum()
# Out:
# key          0
# Wire 1      26
# Wire 2    2002
# Wire 3    3018
# Wire 4    3067
# Wire 5    3080
# Wire 6    3008
# Wire 7    3070
# Wire 8    3062
# Wire 9    3052
# dtype: int64

# %% [markdown]
# 1. Большое количество пропусков
# 2. Названия столбцов необхлодимо привести к "змеинному стилю".

# %% [markdown]
# - **Файл data_wire_time_new.csv**

# %%
df_wire_time_new.head(10)
# Out:
#    key               Wire 1               Wire 2 Wire 3 Wire 4 Wire 5 Wire 6  \
# 0    1  2019-05-03 11:06:19                  NaN    NaN    NaN    NaN    NaN
# 1    2  2019-05-03 11:36:50                  NaN    NaN    NaN    NaN    NaN
# 2    3  2019-05-03 12:11:46                  NaN    NaN    NaN    NaN    NaN
# 3    4  2019-05-03 12:43:22                  NaN    NaN    NaN    NaN    NaN
# 4    5  2019-05-03 13:20:44  2019-05-03 13:15:34    NaN    NaN    NaN    NaN
# 5    6  2019-05-03 13:57:27  2019-05-03 13:48:52    NaN    NaN    NaN    NaN
# 6    7  2019-05-03 14:18:58                  NaN    NaN    NaN    NaN    NaN
# 7    8  2019-05-03 15:01:30                  NaN    NaN    NaN    NaN    NaN
# 8    9  2019-05-03 15:45:44  2019-05-03 15:39:37    NaN    NaN    NaN    NaN
# 9   10  2019-05-03 16:27:00  2019-05-03 16:22:36    NaN    NaN    NaN    NaN
#
#   Wire 7 Wire 8 Wire 9
# 0    NaN    NaN    NaN
# 1    NaN    NaN    NaN
# 2    NaN    NaN    NaN
# 3    NaN    NaN    NaN
# ...

# %%
df_wire_time_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3081 entries, 0 to 3080
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   key     3081 non-null   int64
#  1   Wire 1  3055 non-null   object
#  2   Wire 2  1079 non-null   object
#  3   Wire 3  63 non-null     object
#  4   Wire 4  14 non-null     object
#  5   Wire 5  1 non-null      object
#  6   Wire 6  73 non-null     object
#  7   Wire 7  11 non-null     object
#  8   Wire 8  19 non-null     object
#  9   Wire 9  29 non-null     object
# dtypes: int64(1), object(9)
# memory usage: 240.8+ KB

# %%
df_wire_time_new.isna().sum()
# Out:
# key          0
# Wire 1      26
# Wire 2    2002
# Wire 3    3018
# Wire 4    3067
# Wire 5    3080
# Wire 6    3008
# Wire 7    3070
# Wire 8    3062
# Wire 9    3052
# dtype: int64

# %% [markdown]
# 1. Большое количество пропусков
# 2. Названия столбцов необхлодимо привести к "змеинному стилю".
# 3. Не соответствие типов данных преобразуем из object в datatime

# %% [markdown]
# **Вывод:**
#
# 1. Данные загрузили
# 2. Проведен первичный осмотр данных, имеется значительное количество пропусков в:
#      - `data_bulk_new.csv`
#      - `data_bulk_time_new.csv`
#      - `data_temp_new.csv`
#      - `data_wire_new.csv`
#      - `data_wire_time_new.csv`
#
# 3. Присутствует не соответствие типов данных которые преобразуем из `object` в `datatime`
# 4. Названия столбцов необхлодимо привести к "змеинному стилю".

# %% [markdown]
# <div class="alert alert-success" style="border-color: green; border-radius: 5px">
#     <p><u><b>✅ КОММЕНТАРИЙ МЕНТОРА</b></u></p>
#     <p>
# Первый шаг пройден) тут и аналитика и выводы, принято.
# </p>
# </div>

# %% [markdown]
# ## Исследовательский анализ и предобработка данных

# %% [markdown]
# **Выполните исследовательский анализ каждого датафрейма и при необходимости выполните предобработку. Сделайте выводы об имеющихся признаках: понадобятся ли они для обучения моделей.**

# %%
def histogram_box(df, column):
    fig, axs = plt.subplots(ncols=2, figsize=(16,8))
    sns.set(font_scale=1.10)
    hist_plot = sns.histplot(
        df[column], 
        ax=axs[0], 
        color='purple', 
        bins=50).set_title(f'Распределение {column}', fontsize=20)
    
    sns.boxplot(df[column], ax=axs[1]).set_title(f'Диаграмма размаха {column}', fontsize=20)
    
    print(df[column].describe())

# %% [markdown]
# - **Файл data_arc_new.csv**

# %%
df_arc_new.columns
# Out:
# Index(['key', 'Начало нагрева дугой', 'Конец нагрева дугой',
#        'Активная мощность', 'Реактивная мощность'],
#       dtype='object')

# %%
df_arc_new = df_arc_new.rename(
    columns={
        'Начало нагрева дугой': 'начало_нагрева_дугой',
        'Конец нагрева дугой': 'конец_нагрева_дугой',
        'Активная мощность': 'активная_мощность',
        'Реактивная мощность': 'реактивная_мощность'
    }
)

# %%
df_arc_new.head()
# Out:
#    key начало_нагрева_дугой  конец_нагрева_дугой  активная_мощность  \
# 0    1  2019-05-03 11:02:14  2019-05-03 11:06:02           0.305130
# 1    1  2019-05-03 11:07:28  2019-05-03 11:10:33           0.765658
# 2    1  2019-05-03 11:11:44  2019-05-03 11:14:36           0.580313
# 3    1  2019-05-03 11:18:14  2019-05-03 11:24:19           0.518496
# 4    1  2019-05-03 11:26:09  2019-05-03 11:28:37           0.867133
#
#    реактивная_мощность
# 0             0.211253
# 1             0.477438
# 2             0.430460
# 3             0.379979
# 4             0.643691

# %%
df_arc_new['начало_нагрева_дугой'] = pd.to_datetime(
    df_arc_new['начало_нагрева_дугой'], 
    format='%Y-%m-%d %H:%M:%S')

df_arc_new['конец_нагрева_дугой'] = pd.to_datetime(
    df_arc_new['конец_нагрева_дугой'], 
    format='%Y-%m-%d %H:%M:%S')

# %%
df_arc_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14876 entries, 0 to 14875
# Data columns (total 5 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   key                   14876 non-null  int64
#  1   начало_нагрева_дугой  14876 non-null  datetime64[ns]
#  2   конец_нагрева_дугой   14876 non-null  datetime64[ns]
#  3   активная_мощность     14876 non-null  float64
#  4   реактивная_мощность   14876 non-null  float64
# dtypes: datetime64[ns](2), float64(2), int64(1)
# memory usage: 581.2 KB

# %%
histogram_box(df_arc_new, 'активная_мощность')
# Out:
# count    14876.000000
# mean         0.662752
# std          0.258885
# min          0.223120
# 25%          0.467115
# 50%          0.599587
# 75%          0.830070
# max          1.463773
# Name: активная_мощность, dtype: float64

# %%
histogram_box(df_arc_new, 'реактивная_мощность')
# Out:
# count    14876.000000
# mean         0.438986
# std          5.873485
# min       -715.479924
# 25%          0.337175
# 50%          0.441639
# 75%          0.608201
# max          1.270284
# Name: реактивная_мощность, dtype: float64

# %%
df_arc_new = df_arc_new.query('реактивная_мощность > 0')

# %% [markdown]
# <div class="alert alert-success" style="border-color: green; border-radius: 5px">
#     <p><u><b>✅ КОММЕНТАРИЙ МЕНТОРА</b></u></p>
#     <p>
# есть такое) По идее, если есть подозрение  на некачественные данные, то удаляем весь объект моделирования, т.е. ковш. А не просто строку.
# </p>
# </div>

# %%
histogram_box(df_arc_new, 'реактивная_мощность')
# Out:
# count    14875.000000
# mean         0.487115
# std          0.197612
# min          0.153777
# 25%          0.337190
# 50%          0.441665
# 75%          0.608223
# max          1.270284
# Name: реактивная_мощность, dtype: float64

# %% [markdown]
# Посчитаем полную мощность, которая равна геометрической сумме векторов активной и реактивной мощностей. Эти вектора перпендикулярны, посчитаем их.

# %%
df_arc_new['полная_мощность'] = (df_arc_new['активная_мощность']**2 + \
                                 df_arc_new['реактивная_мощность']**2)**0.5

# %%
df_arc_new.head()
# Out:
#    key начало_нагрева_дугой конец_нагрева_дугой  активная_мощность  \
# 0    1  2019-05-03 11:02:14 2019-05-03 11:06:02           0.305130
# 1    1  2019-05-03 11:07:28 2019-05-03 11:10:33           0.765658
# 2    1  2019-05-03 11:11:44 2019-05-03 11:14:36           0.580313
# 3    1  2019-05-03 11:18:14 2019-05-03 11:24:19           0.518496
# 4    1  2019-05-03 11:26:09 2019-05-03 11:28:37           0.867133
#
#    реактивная_мощность  полная_мощность
# 0             0.211253         0.371123
# 1             0.477438         0.902319
# 2             0.430460         0.722536
# 3             0.379979         0.642824
# 4             0.643691         1.079934

# %% [markdown]
# Вычислим общее время нагрева

# %%
df_arc_new['общее_время_нагрева'] = df_arc_new['конец_нагрева_дугой'] - df_arc_new['начало_нагрева_дугой']
df_arc_new['общее_время_нагрева'] = df_arc_new['общее_время_нагрева'].dt.seconds

# %%
df_arc_new.head()
# Out:
#    key начало_нагрева_дугой конец_нагрева_дугой  активная_мощность  \
# 0    1  2019-05-03 11:02:14 2019-05-03 11:06:02           0.305130
# 1    1  2019-05-03 11:07:28 2019-05-03 11:10:33           0.765658
# 2    1  2019-05-03 11:11:44 2019-05-03 11:14:36           0.580313
# 3    1  2019-05-03 11:18:14 2019-05-03 11:24:19           0.518496
# 4    1  2019-05-03 11:26:09 2019-05-03 11:28:37           0.867133
#
#    реактивная_мощность  полная_мощность  общее_время_нагрева
# 0             0.211253         0.371123                  228
# 1             0.477438         0.902319                  185
# 2             0.430460         0.722536                  172
# 3             0.379979         0.642824                  365
# 4             0.643691         1.079934                  148

# %% [markdown]
# <div class="alert alert-success" style="border-color: green; border-radius: 5px">
#     <p><u><b>✅ КОММЕНТАРИЙ МЕНТОРА</b></u></p>
#     <p>новые факторы в деле)</p>
# </div>

# %% [markdown]
# Посчитаем затраты электроэнергии

# %%
df_arc_new['затраты_электроэнергии'] = df_arc_new['полная_мощность'] * df_arc_new['общее_время_нагрева']

# %%
df_arc_new.head()
# Out:
#    key начало_нагрева_дугой конец_нагрева_дугой  активная_мощность  \
# 0    1  2019-05-03 11:02:14 2019-05-03 11:06:02           0.305130
# 1    1  2019-05-03 11:07:28 2019-05-03 11:10:33           0.765658
# 2    1  2019-05-03 11:11:44 2019-05-03 11:14:36           0.580313
# 3    1  2019-05-03 11:18:14 2019-05-03 11:24:19           0.518496
# 4    1  2019-05-03 11:26:09 2019-05-03 11:28:37           0.867133
#
#    реактивная_мощность  полная_мощность  общее_время_нагрева  \
# 0             0.211253         0.371123                  228
# 1             0.477438         0.902319                  185
# 2             0.430460         0.722536                  172
# 3             0.379979         0.642824                  365
# 4             0.643691         1.079934                  148
#
#    затраты_электроэнергии
# 0               84.616003
# 1              166.928978
# 2              124.276277
# 3              234.630603
# 4              159.830252

# %% [markdown]
# <div class="alert alert-success" style="border-color: green; border-radius: 5px">
#     <p><u><b>✅ КОММЕНТАРИЙ МЕНТОРА</b></u></p>
#     <p>понятно, согласен.</p>
# </div>

# %%
df_arc_new = df_arc_new.groupby(by='key').sum()
df_arc_new.head()
# Out:
#      активная_мощность  реактивная_мощность  полная_мощность  \
# key
# 1             3.036730             2.142821         3.718736
# 2             2.139408             1.453357         2.588349
# 3             4.063641             2.937457         5.019223
# 4             2.706489             2.056992         3.400038
# 5             2.252950             1.687991         2.816980
#
#      общее_время_нагрева  затраты_электроэнергии
# key
# 1                   1098              770.282114
# 2                    811              481.760005
# 3                    655              722.837668
# 4                    741              683.455597
# 5                    869              512.169934

# %%
histogram_box(df_arc_new, 'полная_мощность')
# Out:
# count    3214.000000
# mean        3.810779
# std         1.502804
# min         0.331897
# 25%         2.775306
# 50%         3.694219
# 75%         4.696915
# max        15.288271
# Name: полная_мощность, dtype: float64

# %%
histogram_box(df_arc_new, 'общее_время_нагрева')
# Out:
# count    3214.000000
# mean      794.545115
# std       332.491076
# min        57.000000
# 25%       571.000000
# 50%       770.000000
# 75%       983.000000
# max      4189.000000
# Name: общее_время_нагрева, dtype: float64

# %%
histogram_box(df_arc_new, 'затраты_электроэнергии')
# Out:
# count    3214.000000
# mean      655.569107
# std       308.976732
# min        33.430208
# 25%       444.626580
# 50%       620.101427
# 75%       827.671845
# max      4546.405812
# Name: затраты_электроэнергии, dtype: float64

# %%
df_arc_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3214 entries, 1 to 3241
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   активная_мощность       3214 non-null   float64
#  1   реактивная_мощность     3214 non-null   float64
#  2   полная_мощность         3214 non-null   float64
#  3   общее_время_нагрева     3214 non-null   int64
#  4   затраты_электроэнергии  3214 non-null   float64
# dtypes: float64(4), int64(1)
# memory usage: 150.7 KB

# %% [markdown]
# После создания новых признаков и группировки данных видим что новые признаки имеют колокообразное распределение данных, а также определенное количество выбросов, которые пока трогать не будем, так как это может повлиять на дальнейшие расчеты.

# %% [markdown]
# <div class="alert alert-success" style="border-color: green; border-radius: 5px">
#     <p><u><b>✅ КОММЕНТАРИЙ МЕНТОРА</b></u></p>
#     <p>
# графический анализ - в точку)
# </p>
# </div>

# %% [markdown]
# - **Файл data_bulk_new.csv**

# %%
df_bulk_new.head()
# Out:
#    key  Bulk 1  Bulk 2  Bulk 3  Bulk 4  Bulk 5  Bulk 6  Bulk 7  Bulk 8  \
# 0    1     NaN     NaN     NaN    43.0     NaN     NaN     NaN     NaN
# 1    2     NaN     NaN     NaN    73.0     NaN     NaN     NaN     NaN
# 2    3     NaN     NaN     NaN    34.0     NaN     NaN     NaN     NaN
# 3    4     NaN     NaN     NaN    81.0     NaN     NaN     NaN     NaN
# 4    5     NaN     NaN     NaN    78.0     NaN     NaN     NaN     NaN
#
#    Bulk 9  Bulk 10  Bulk 11  Bulk 12  Bulk 13  Bulk 14  Bulk 15
# 0     NaN      NaN      NaN    206.0      NaN    150.0    154.0
# 1     NaN      NaN      NaN    206.0      NaN    149.0    154.0
# 2     NaN      NaN      NaN    205.0      NaN    152.0    153.0
# 3     NaN      NaN      NaN    207.0      NaN    153.0    154.0
# 4     NaN      NaN      NaN    203.0      NaN    151.0    152.0

# %%
df_bulk_new = df_bulk_new.rename(
    columns={
        'Bulk 1':'bulk_1',
        'Bulk 2':'bulk_2', 
        'Bulk 3':'bulk_3', 
        'Bulk 4':'bulk_4', 
        'Bulk 5':'bulk_5', 
        'Bulk 6':'bulk_6',
        'Bulk 7':'bulk_7', 
        'Bulk 8':'bulk_8', 
        'Bulk 9':'bulk_9', 
        'Bulk 10':'bulk_10', 
        'Bulk 11':'bulk_11', 
        'Bulk 12':'bulk_12',
        'Bulk 13':'bulk_13', 
        'Bulk 14':'bulk_14', 
        'Bulk 15':'bulk_15'
    }
)

# %%
df_bulk_new.columns
# Out:
# Index(['key', 'bulk_1', 'bulk_2', 'bulk_3', 'bulk_4', 'bulk_5', 'bulk_6',
#        'bulk_7', 'bulk_8', 'bulk_9', 'bulk_10', 'bulk_11', 'bulk_12',
#        'bulk_13', 'bulk_14', 'bulk_15'],
#       dtype='object')

# %%
pd.DataFrame(round(df_bulk_new.isna().mean() * 100, 1))
# Out:
#              0
# key        0.0
# bulk_1    91.9
# bulk_2    99.3
# bulk_3    58.5
# bulk_4    67.6
# bulk_5    97.5
# bulk_6    81.6
# bulk_7    99.2
# bulk_8   100.0
# bulk_9    99.4
# bulk_10   94.4
# bulk_11   94.3
# bulk_12   21.7
# bulk_13   99.4
# bulk_14   10.3
# bulk_15   28.2

# %% [markdown]
# Так как имеем большое количество пропусков в данных более 80%, то избавтмся от них.

# %%
df_bulk_new.drop(['bulk_1', 
                  'bulk_2', 
                  'bulk_5', 
                  'bulk_6', 
                  'bulk_7', 
                  'bulk_8', 
                  'bulk_9', 
                  'bulk_10', 
                  'bulk_11', 
                  'bulk_13'],
                 axis=1, 
                 inplace=True)

# %%
df_bulk_new.isna().sum()
# Out:
# key           0
# bulk_3     1831
# bulk_4     2115
# bulk_12     679
# bulk_14     323
# bulk_15     881
# dtype: int64

# %% [markdown]
# Заполним пропуски нулевыми значениями

# %%
df_bulk_new = df_bulk_new.fillna(0)
df_bulk_new.isna().sum()
# Out:
# key        0
# bulk_3     0
# bulk_4     0
# bulk_12    0
# bulk_14    0
# bulk_15    0
# dtype: int64

# %% [markdown]
# <div class="alert alert-success" style="border-color: green; border-radius: 5px">
#     <p><u><b>✅ КОММЕНТАРИЙ МЕНТОРА</b></u></p>
#     <p>согласен</p>
# </div>

# %%
df_bulk_new = df_bulk_new.astype('int64')
df_bulk_new.head()
# Out:
#    key  bulk_3  bulk_4  bulk_12  bulk_14  bulk_15
# 0    1       0      43      206      150      154
# 1    2       0      73      206      149      154
# 2    3       0      34      205      152      153
# 3    4       0      81      207      153      154
# 4    5       0      78      203      151      152

# %% [markdown]
# - **Файл data_gas_new.csv**

# %%
df_gas_new.head()
# Out:
#    key      Газ 1
# 0    1  29.749986
# 1    2  12.555561
# 2    3  28.554793
# 3    4  18.841219
# 4    5   5.413692

# %%
df_gas_new.columns
# Out:
# Index(['key', 'Газ 1'], dtype='object')

# %%
df_gas_new = df_gas_new.rename(
    columns={
        'Газ 1':'газ_1'
    }
)

# %%
histogram_box(df_gas_new, 'газ_1')
# Out:
# count    3239.000000
# mean       11.002062
# std         6.220327
# min         0.008399
# 25%         7.043089
# 50%         9.836267
# 75%        13.769915
# max        77.995040
# Name: газ_1, dtype: float64

# %% [markdown]
# - **Файл data_temp_new.csv**

# %%
df_temp_new.head()
# Out:
#    key         Время замера  Температура
# 0    1  2019-05-03 11:02:04       1571.0
# 1    1  2019-05-03 11:07:18       1604.0
# 2    1  2019-05-03 11:11:34       1618.0
# 3    1  2019-05-03 11:18:04       1601.0
# 4    1  2019-05-03 11:25:59       1606.0

# %%
df_temp_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18092 entries, 0 to 18091
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   key           18092 non-null  int64
#  1   Время замера  18092 non-null  object
#  2   Температура   14665 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 424.2+ KB

# %%
df_temp_new.columns
# Out:
# Index(['key', 'Время замера', 'Температура'], dtype='object')

# %%
df_temp_new = df_temp_new.rename(
    columns={
        'Время замера':'время_замера',
        'Температура': 'температура'
    }
)

# %%
df_temp_new['время_замера'] = pd.to_datetime(
    df_temp_new['время_замера'], 
    format='%Y-%m-%d %H:%M:%S')

# %%
df_temp_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18092 entries, 0 to 18091
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   key           18092 non-null  int64
#  1   время_замера  18092 non-null  datetime64[ns]
#  2   температура   14665 non-null  float64
# dtypes: datetime64[ns](1), float64(1), int64(1)
# memory usage: 424.2 KB

# %%
histogram_box(df_temp_new, 'температура')
# Out:
# count    14665.000000
# mean      1590.722741
# std         20.394381
# min       1191.000000
# 25%       1580.000000
# 50%       1590.000000
# 75%       1599.000000
# max       1705.000000
# Name: температура, dtype: float64

# %%
df_temp_new = df_temp_new.query('температура > 1500')

# %% [markdown]
# <div class="alert alert-success" style="border-color: green; border-radius: 5px">
#     <p><u><b>✅ КОММЕНТАРИЙ МЕНТОРА</b></u></p>
#     <p>согласен. Но, кк и пи сал в прошлый раз, лучше именно объект моделирования удалть)</p>
# </div>

# %%
histogram_box(df_temp_new, 'температура')
# Out:
# count    14660.000000
# mean      1590.852729
# std         19.143141
# min       1515.000000
# 25%       1580.000000
# 50%       1590.000000
# 75%       1599.000000
# max       1705.000000
# Name: температура, dtype: float64

# %%
pd.DataFrame(round(df_temp_new.isna().mean()*100, 1))
# Out:
#                 0
# key           0.0
# время_замера  0.0
# температура   0.0

# %%
metering = df_temp_new['key'].value_counts() \
.reset_index(name='измерение_циклов') \
.rename(columns={'index': 'key'}) \
.sort_values(by='key', ascending=False)

# %%
metering.query('измерение_циклов > 1').head(10)
# Out:
#        key  измерение_циклов
# 1712  2499                 5
# 968   2498                 6
# 2298  2497                 4
# 602   2496                 7
# 1420  2495                 5
# 1965  2494                 4
# 2122  2493                 4
# 2025  2492                 4
# 966   2490                 6
# 2342  2489                 3

# %% [markdown]
# <div class="alert alert-success" style="border-color: green; border-radius: 5px">
#     <p><u><b>✅ КОММЕНТАРИЙ МЕНТОРА</b></u></p>
#     <p>Важная часть проекта - отобрать только нужные ковши, принято.</p>
# </div>

# %% [markdown]
# Добавим новый признак, разницу между последним и начальным замером температуры.

# %%
df_temp_new_update = df_temp_new.groupby(by='key').agg(['first', 'last']).reset_index()
df_temp_new_update.columns = ['key', 'начальный_замер', 'конечный_замер', 'начальная_температура', 'конечная_температура']
df_temp_new_update['разница_замера'] = df_temp_new_update['конечный_замер'] - df_temp_new_update['начальный_замер']
df_temp_new_update['разница_замера'] = df_temp_new_update['разница_замера'].dt.seconds
df_temp_new_update = df_temp_new_update.query('key < 2500')

# %%
df_temp_new_update.head()
# Out:
#    key     начальный_замер      конечный_замер  начальная_температура  \
# 0    1 2019-05-03 11:02:04 2019-05-03 11:30:38                 1571.0
# 1    2 2019-05-03 11:34:04 2019-05-03 11:55:09                 1581.0
# 2    3 2019-05-03 12:06:44 2019-05-03 12:35:57                 1596.0
# 3    4 2019-05-03 12:39:27 2019-05-03 12:59:47                 1601.0
# 4    5 2019-05-03 13:11:03 2019-05-03 13:36:39                 1576.0
#
#    конечная_температура  разница_замера
# 0                1613.0            1714
# 1                1602.0            1265
# 2                1599.0            1753
# 3                1625.0            1220
# 4                1602.0            1536

# %%
df_temp_new_update.tail()
# Out:
#        key     начальный_замер      конечный_замер  начальная_температура  \
# 2472  2495 2019-08-10 11:27:47 2019-08-10 11:50:47                 1570.0
# 2473  2496 2019-08-10 11:56:48 2019-08-10 12:25:13                 1554.0
# 2474  2497 2019-08-10 12:37:26 2019-08-10 12:53:28                 1571.0
# 2475  2498 2019-08-10 12:58:11 2019-08-10 13:23:31                 1591.0
# 2476  2499 2019-08-10 13:33:21 2019-08-10 13:58:58                 1569.0
#
#       конечная_температура  разница_замера
# 2472                1591.0            1380
# 2473                1591.0            1705
# 2474                1589.0             962
# 2475                1594.0            1520
# 2476                1603.0            1537

# %% [markdown]
# <div class="alert alert-success" style="border-color: green; border-radius: 5px">
#     <p><u><b>✅ КОММЕНТАРИЙ МЕНТОРА</b></u></p>
#     <p>ОК</p>
# </div>

# %% [markdown]
# - **Файл data_wire_new.csv**

# %%
df_wire_new.head()
# Out:
#    key     Wire 1   Wire 2  Wire 3  Wire 4  Wire 5  Wire 6  Wire 7  Wire 8  \
# 0    1  60.059998      NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1    2  96.052315      NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2    3  91.160157      NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 3    4  89.063515      NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4    5  89.238236  9.11456     NaN     NaN     NaN     NaN     NaN     NaN
#
#    Wire 9
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %%
df_wire_new.columns
# Out:
# Index(['key', 'Wire 1', 'Wire 2', 'Wire 3', 'Wire 4', 'Wire 5', 'Wire 6',
#        'Wire 7', 'Wire 8', 'Wire 9'],
#       dtype='object')

# %%
df_wire_new = df_wire_new.rename(
    columns={
        'Wire 1': 'wire_1', 
        'Wire 2': 'wire_2', 
        'Wire 3': 'wire_3', 
        'Wire 4': 'wire_4', 
        'Wire 5': 'wire_5', 
        'Wire 6': 'wire_6',
        'Wire 7': 'wire_7', 
        'Wire 8': 'wire_8', 
        'Wire 9': 'wire_9'
    }
)

# %%
pd.DataFrame(round(df_wire_new.isna().mean()*100, 1))
# Out:
#             0
# key       0.0
# wire_1    0.8
# wire_2   65.0
# wire_3   98.0
# wire_4   99.5
# wire_5  100.0
# wire_6   97.6
# wire_7   99.6
# wire_8   99.4
# wire_9   99.1

# %% [markdown]
# Видим большой процент пропусков, избавимся от них.

# %%
df_wire_new.drop(['wire_3', 'wire_4', 'wire_5', 'wire_6', 'wire_7', 'wire_8', 'wire_9'],
                 axis=1, 
                 inplace=True)

# %%
df_wire_new = df_wire_new.fillna(0)

# %% [markdown]
# <div class="alert alert-success" style="border-color: green; border-radius: 5px">
#     <p><u><b>✅ КОММЕНТАРИЙ МЕНТОРА</b></u></p>
#     <p>ок)</p>
# </div>

# %%
df_wire_new.head()
# Out:
#    key     wire_1   wire_2
# 0    1  60.059998  0.00000
# 1    2  96.052315  0.00000
# 2    3  91.160157  0.00000
# 3    4  89.063515  0.00000
# 4    5  89.238236  9.11456

# %% [markdown]
# **Вывод:**
#
# 1. Проведена предобработка данных:
#     - типы данных преобразованы
#     - названия столбцов приведен к "змеинному стилю"
#     - обработаны пропуски в данных
#     - добавлены дополнительные признаки
#     - данные подготовлены к объединению в общий датасет
#
# 2. Проведен иследовательский анализ данных. Распределение данных нормальное, в диаграммах размаха видны аномальные значения, которое решено не трогать, чтобы не искажать данные в дальнейших вычислениях.

# %% [markdown]
# <div class="alert alert-success" style="border-color: green; border-radius: 5px">
#     <p><u><b>✅ КОММЕНТАРИЙ МЕНТОРА</b></u></p>
#     <p>Чёткий раздел получился) И аналитика, и графика, и выводы, принято.</p>
# </div>

# %% [markdown]
# ## Объединение данных

# %% [markdown]
# **Объедините выбранные вами признаки в один датафрейм по ключу.**

# %% [markdown]
# В объединении данных используем все датафреймы, кроме `data_bulk_time_new.csv` и `data_wire_time_new.csv`.

# %%
data_all = df_arc_new.merge(df_temp_new_update, on='key', how='inner')
data_all = data_all.merge(df_gas_new, on='key', how='inner')
data_all = data_all.merge(df_bulk_new, on='key', how='inner')
data_all = data_all.merge(df_wire_new, on='key', how='inner')

# %%
data_all.head()
# Out:
#    key  активная_мощность  реактивная_мощность  полная_мощность  \
# 0    1           3.036730             2.142821         3.718736
# 1    2           2.139408             1.453357         2.588349
# 2    3           4.063641             2.937457         5.019223
# 3    4           2.706489             2.056992         3.400038
# 4    5           2.252950             1.687991         2.816980
#
#    общее_время_нагрева  затраты_электроэнергии     начальный_замер  \
# 0                 1098              770.282114 2019-05-03 11:02:04
# 1                  811              481.760005 2019-05-03 11:34:04
# 2                  655              722.837668 2019-05-03 12:06:44
# 3                  741              683.455597 2019-05-03 12:39:27
# 4                  869              512.169934 2019-05-03 13:11:03
#
#        конечный_замер  начальная_температура  конечная_температура  \
# 0 2019-05-03 11:30:38                 1571.0                1613.0
# ...

# %%
data_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2329 entries, 0 to 2328
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   key                     2329 non-null   int64
#  1   активная_мощность       2329 non-null   float64
#  2   реактивная_мощность     2329 non-null   float64
#  3   полная_мощность         2329 non-null   float64
#  4   общее_время_нагрева     2329 non-null   int64
#  5   затраты_электроэнергии  2329 non-null   float64
#  6   начальный_замер         2329 non-null   datetime64[ns]
#  7   конечный_замер          2329 non-null   datetime64[ns]
#  8   начальная_температура   2329 non-null   float64
#  9   конечная_температура    2329 non-null   float64
#  10  разница_замера          2329 non-null   int64
#  11  газ_1                   2329 non-null   float64
#  12  bulk_3                  2329 non-null   int64
#  13  bulk_4                  2329 non-null   int64
# ...

# %%
data_all.isna().sum()
# Out:
# key                       0
# активная_мощность         0
# реактивная_мощность       0
# полная_мощность           0
# общее_время_нагрева       0
# затраты_электроэнергии    0
# начальный_замер           0
# конечный_замер            0
# начальная_температура     0
# конечная_температура      0
# разница_замера            0
# газ_1                     0
# bulk_3                    0
# bulk_4                    0
# bulk_12                   0
# bulk_14                   0
# bulk_15                   0
# wire_1                    0
# wire_2                    0
# dtype: int64

# %% [markdown]
# <div class="alert alert-success" style="border-color: green; border-radius: 5px">
#     <p><u><b>✅ КОММЕНТАРИЙ МЕНТОРА</b></u></p>
#     <p>
# мержевание по иннер, согласен!)
# </p>
# </div>

# %%
data_all.duplicated().sum()
# Out:
# 0

# %%
data_all.drop(['key', 'начальный_замер', 'конечный_замер'], axis=1, inplace=True)

# %%
data_all.head()
# Out:
#    активная_мощность  реактивная_мощность  полная_мощность  \
# 0           3.036730             2.142821         3.718736
# 1           2.139408             1.453357         2.588349
# 2           4.063641             2.937457         5.019223
# 3           2.706489             2.056992         3.400038
# 4           2.252950             1.687991         2.816980
#
#    общее_время_нагрева  затраты_электроэнергии  начальная_температура  \
# 0                 1098              770.282114                 1571.0
# 1                  811              481.760005                 1581.0
# 2                  655              722.837668                 1596.0
# 3                  741              683.455597                 1601.0
# 4                  869              512.169934                 1576.0
#
#    конечная_температура  разница_замера      газ_1  bulk_3  bulk_4  bulk_12  \
# 0                1613.0            1714  29.749986       0      43      206
# ...

# %% [markdown]
# **Вывод:**
#
# - Объедтнили по признаку `key` необходимые датасеты в итоговый;
# - Пропуски и дубликаты отсутствуют;
# - Убрали ненужные прихнаки для дальнейшей работы с данными;

# %% [markdown]
# <div class="alert alert-success" style="border-color: green; border-radius: 5px">
#     <p><u><b>✅ КОММЕНТАРИЙ МЕНТОРА</b></u></p>
#     <p>идём дальше).</p>
# </div>

# %% [markdown]
# ## Исследовательский анализ и предобработка данных объединённого датафрейма

# %% [markdown]
# **Выполните исследовательский анализ объединённого датафрейма, визуализируйте распределения признаков и при необходимости выполните предобработку. Проведите корреляционный анализ. Напоминаем, что вы можете использовать не только имеющиеся признаки, но и генерировать новые.**

# %%
data_all.columns
# Out:
# Index(['активная_мощность', 'реактивная_мощность', 'полная_мощность',
#        'общее_время_нагрева', 'затраты_электроэнергии',
#        'начальная_температура', 'конечная_температура', 'разница_замера',
#        'газ_1', 'bulk_3', 'bulk_4', 'bulk_12', 'bulk_14', 'bulk_15', 'wire_1',
#        'wire_2'],
#       dtype='object')

# %%
histogram_box(data_all, 'активная_мощность')
# Out:
# count    2329.000000
# mean        3.125033
# std         1.221007
# min         0.267676
# 25%         2.293900
# 50%         3.035365
# 75%         3.834300
# max        12.375636
# Name: активная_мощность, dtype: float64

# %%
histogram_box(data_all, 'реактивная_мощность')
# Out:
# count    2329.000000
# mean        2.300522
# std         0.903968
# min         0.196228
# 25%         1.669572
# 50%         2.225398
# 75%         2.829159
# max         8.949049
# Name: реактивная_мощность, dtype: float64

# %%
histogram_box(data_all, 'полная_мощность')
# Out:
# count    2329.000000
# mean        3.884654
# std         1.518157
# min         0.331897
# 25%         2.843058
# 50%         3.767499
# 75%         4.769421
# max        15.288271
# Name: полная_мощность, dtype: float64

# %%
histogram_box(data_all, 'общее_время_нагрева')
# Out:
# count    2329.000000
# mean      807.600687
# std       340.897332
# min        57.000000
# 25%       581.000000
# 50%       778.000000
# 75%       993.000000
# max      4189.000000
# Name: общее_время_нагрева, dtype: float64

# %%
histogram_box(data_all, 'затраты_электроэнергии')
# Out:
# count    2329.000000
# mean      669.741514
# std       319.531949
# min        33.430208
# 25%       457.864703
# 50%       630.714148
# 75%       841.398018
# max      4546.405812
# Name: затраты_электроэнергии, dtype: float64

# %%
histogram_box(data_all, 'начальная_температура')
# Out:
# count    2329.000000
# mean     1587.386003
# std        23.619841
# min      1519.000000
# 25%      1571.000000
# 50%      1587.000000
# 75%      1603.000000
# max      1660.000000
# Name: начальная_температура, dtype: float64

# %%
histogram_box(data_all, 'конечная_температура')
# Out:
# count    2329.000000
# mean     1593.365393
# std        11.200915
# min      1541.000000
# 25%      1587.000000
# 50%      1593.000000
# 75%      1598.000000
# max      1653.000000
# Name: конечная_температура, dtype: float64

# %%
histogram_box(data_all, 'разница_замера')
# Out:
# count     2329.000000
# mean      2321.810219
# std       1385.191527
# min        270.000000
# 25%       1579.000000
# 50%       2045.000000
# 75%       2791.000000
# max      23674.000000
# Name: разница_замера, dtype: float64

# %%
histogram_box(data_all, 'газ_1')
# Out:
# count    2329.000000
# mean       11.375600
# std         6.392041
# min         0.008399
# 25%         7.282948
# 50%        10.100950
# 75%        14.216688
# max        77.995040
# Name: газ_1, dtype: float64

# %%
histogram_box(data_all, 'bulk_3')
# Out:
# count    2329.000000
# mean       47.348218
# std        75.310430
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%        80.000000
# max       454.000000
# Name: bulk_3, dtype: float64

# %%
histogram_box(data_all, 'bulk_4')
# Out:
# count    2329.000000
# mean       37.303564
# std        58.643238
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%        77.000000
# max       281.000000
# Name: bulk_4, dtype: float64

# %%
histogram_box(data_all, 'bulk_12')
# Out:
# count    2329.000000
# mean      208.415629
# std       157.062272
# min         0.000000
# 25%       105.000000
# 50%       206.000000
# 75%       282.000000
# max      1849.000000
# Name: bulk_12, dtype: float64

# %%
histogram_box(data_all, 'bulk_14')
# Out:
# count    2329.000000
# mean      153.853585
# std        81.404354
# min         0.000000
# 25%       105.000000
# 50%       149.000000
# 75%       204.000000
# max       636.000000
# Name: bulk_14, dtype: float64

# %%
histogram_box(data_all, 'bulk_15')
# Out:
# count    2329.000000
# mean      119.952769
# std        84.640443
# min         0.000000
# 25%         0.000000
# 50%       107.000000
# 75%       204.000000
# max       405.000000
# Name: bulk_15, dtype: float64

# %%
histogram_box(data_all, 'wire_1')
# Out:
# count    2329.000000
# mean      102.443601
# std        43.539993
# min         0.000000
# 25%        73.207679
# 50%       101.119201
# 75%       128.091599
# max       330.314424
# Name: wire_1, dtype: float64

# %%
histogram_box(data_all, 'wire_2')
# Out:
# count    2329.000000
# mean       17.609859
# std        33.624771
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%        23.102560
# max       282.780152
# Name: wire_2, dtype: float64

# %% [markdown]
# Построили графики всех признаков из нового датасета. В большинстве у нас нормальные распределения признаков, кроме признаков `bulk_3, bulk_4, bulk_15 и wire_2`. Выбросы пока трогать не будем. Посмотрим на тепловую карту датасета.

# %% [markdown]
# <div class="alert alert-success" style="border-color: green; border-radius: 5px">
#     <p><u><b>✅ КОММЕНТАРИЙ МЕНТОРА</b></u></p>
# </b><br>👍

# %%
plt.figure(figsize=(20, 15))
fig = sns.heatmap(data_all.corr(), cmap='coolwarm', annot=True)
plt.title('Матрица корреляции признаков', fontsize='15')
plt.setp(fig.get_xticklabels(), rotation=90)
plt.show()

# %% [markdown]
# **Вывод:**
#
# 1. Построили графики всех признаков из нового датасета. В большинстве у нас нормальные распределения признаков, кроме признаков `bulk_3, bulk_4, bulk_15 и wire_2`.
#
# 2. Тепловая карта показывает, что существует высокая корелляция признаков между `'активная_мощность', 'реактивная_мощность', 'полная_мощность'`

# %%
data_all
# Out:
#       активная_мощность  реактивная_мощность  полная_мощность  \
# 0              3.036730             2.142821         3.718736
# 1              2.139408             1.453357         2.588349
# 2              4.063641             2.937457         5.019223
# 3              2.706489             2.056992         3.400038
# 4              2.252950             1.687991         2.816980
# ...                 ...                  ...              ...
# 2324           3.168133             2.210936         3.868721
# 2325           4.174918             2.872031         5.070316
# 2326           3.605239             2.452092         4.360918
# 2327           3.202310             2.239820         3.909917
# 2328           1.737084             1.296836         2.169252
#
#       общее_время_нагрева  затраты_электроэнергии  начальная_температура  \
# 0                    1098              770.282114                 1571.0
# ...

# %% [markdown]
# <div class="alert alert-success" style="border-color: green; border-radius: 5px">
#     <p><u><b>✅ КОММЕНТАРИЙ МЕНТОРА</b></u></p>
#     <p>верно. А если так, то стоит лишние факторы удалять. Особенно, если использоваться будет линейная регрессия</p>
# </div>

# %% [markdown]
# ## Подготовка данных

# %% [markdown]
# **Выполните подготовку данных для обучения модели. Разделите данные на две выборки, при масштабировании и кодировании учитывайте особенности данных и моделей.**

# %%
X = data_all.drop('конечная_температура', axis=1)
y = data_all['конечная_температура']

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=RANDOM_STATE, test_size=TEST_SIZE)

# %%
print('X_train = ', X_train.shape)
print('y_train = ', y_train.shape)
print('-'*20)
print('X_test = ', X_test.shape)
print('y_test = ', y_test.shape)
# Out:
# X_train =  (1746, 15)
# y_train =  (1746,)
# --------------------
# X_test =  (583, 15)
# y_test =  (583,)

# %% [markdown]
# **Вывод:**
#
#
# 1. подготовку двнных выполнили
# 2. данные разделили на выборки
# 3. размеры выборок:
#    - `X_train = (1746, 15)`
#    - `y_train = (1746,)`
#    - `X_test  = (583, 15)`
#    - `y_test  = (583,)`

# %% [markdown]
# <div class="alert alert-success" style="border-color: green; border-radius: 5px">
#     <p><u><b>✅ КОММЕНТАРИЙ МЕНТОРА</b></u></p>
# принято    <p>
# </p>
# </div>

# %% [markdown]
# ## Обучение моделей машинного обучения

# %% [markdown]
# **Обучите как минимум две модели. Хотя бы для одной из них подберите как минимум два гиперпараметра.
# Критерии оценки: значения метрики `MAE <= 6.8`**

# %% [markdown]
# - **RandomForestRegressor**

# %%
modelRandomForestRegressor = RandomForestRegressor()

param = {
    'n_estimators':[10, 50, 100],
    'max_depth': [5, 10, 15],
    'min_samples_split': [2, 4, 8],
    'bootstrap': [True, False],
    'random_state': [RANDOM_STATE]
}

randomForestGridSearchCV = GridSearchCV(
    modelRandomForestRegressor, 
    param, 
    cv=5, 
    scoring='neg_mean_absolute_error'
)

randomForestGridSearchCV.fit(X_train, y_train)

model_result = round(abs(randomForestGridSearchCV.best_score_), 2)

# %%
print('Лучшие параметры модели: ', randomForestGridSearchCV.best_params_)
print('MAE для тренировочных данных: ', model_result)
# Out:
# Лучшие параметры модели:  {'bootstrap': True, 'max_depth': 15, 'min_samples_split': 4, 'n_estimators': 100, 'random_state': 11024}
# MAE для тренировочных данных:  6.22

# %% [markdown]
# <div class="alert alert-success" style="border-color: green; border-radius: 5px">
#     <p><u><b>✅ КОММЕНТАРИЙ МЕНТОРА</b></u></p>
#     <p>Впервый пошёл)</p>
# </div>

# %% [markdown]
# - **CatBoostRegressor**

# %%
modelCatBoostRegressor = CatBoostRegressor(verbose=False)

param = {
    'loss_function': ['MAE'],
    'depth': [5],
    'learning_rate': [0.1],
    'n_estimators': [500],
    'random_state': [RANDOM_STATE]   
}

catBoostGridSearchCV = GridSearchCV( 
    modelCatBoostRegressor, 
    param, 
    cv=5, 
    verbose=2,
    scoring='neg_mean_absolute_error'
)

catBoostGridSearchCV.fit(X_train, y_train)

model_result_cbr = round(abs(catBoostGridSearchCV.best_score_), 2)
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END depth=5, learning_rate=0.1, loss_function=MAE, n_estimators=500, random_state=11024; total time=   1.9s
# [CV] END depth=5, learning_rate=0.1, loss_function=MAE, n_estimators=500, random_state=11024; total time=   1.8s
# [CV] END depth=5, learning_rate=0.1, loss_function=MAE, n_estimators=500, random_state=11024; total time=   1.9s
# [CV] END depth=5, learning_rate=0.1, loss_function=MAE, n_estimators=500, random_state=11024; total time=   1.9s
# [CV] END depth=5, learning_rate=0.1, loss_function=MAE, n_estimators=500, random_state=11024; total time=   1.7s

# %%
print('Лучшие параметры модели: ', catBoostGridSearchCV.best_params_)
print('MAE для тренировочных данных: ', model_result_cbr)
# Out:
# Лучшие параметры модели:  {'depth': 5, 'learning_rate': 0.1, 'loss_function': 'MAE', 'n_estimators': 500, 'random_state': 11024}
# MAE для тренировочных данных:  6.11

# %% [markdown]
# <div class="alert alert-success" style="border-color: green; border-radius: 5px">
#     <p><u><b>✅ КОММЕНТАРИЙ МЕНТОРА</b></u></p>
#     <p>тут без гиперпараметров) ок</p>
# </div>

# %% [markdown]
# - **LGBMRegressor**

# %%
modelLGBMRegressor = LGBMRegressor()

param = {
    'metric': ['MAE'],
    'max_depth': [10],
    'num_leaves': [10],
    'learning_rate': [0.05],
    'random_state': [RANDOM_STATE]   
}

lgbmRegressorGridSearchCV = GridSearchCV( 
    modelLGBMRegressor, 
    param, 
    cv=5, 
    verbose=2,
    scoring='neg_mean_absolute_error'
)

lgbmRegressorGridSearchCV.fit(X_train, y_train)

model_result_lgbm = round(abs(lgbmRegressorGridSearchCV.best_score_), 2)
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV] END learning_rate=0.05, max_depth=10, metric=MAE, num_leaves=10, random_state=11024; total time=   0.7s
# [CV] END learning_rate=0.05, max_depth=10, metric=MAE, num_leaves=10, random_state=11024; total time=   0.6s
# [CV] END learning_rate=0.05, max_depth=10, metric=MAE, num_leaves=10, random_state=11024; total time=   1.6s
# [CV] END learning_rate=0.05, max_depth=10, metric=MAE, num_leaves=10, random_state=11024; total time=   1.6s
# [CV] END learning_rate=0.05, max_depth=10, metric=MAE, num_leaves=10, random_state=11024; total time=   0.6s

# %%
print('Лучшие параметры модели: ', lgbmRegressorGridSearchCV.best_params_)
print('MAE для тренировочных данных: ', model_result_lgbm)
# Out:
# Лучшие параметры модели:  {'learning_rate': 0.05, 'max_depth': 10, 'metric': 'MAE', 'num_leaves': 10, 'random_state': 11024}
# MAE для тренировочных данных:  6.06

# %% [markdown]
# **Вывод:**
#
# 1. Обучили 3 модели:
#    - `RandomForestRegressor`
#    - `CatBoostRegressor`
#    - `LGBMRegressor`
#
# 2. Получили следующие результаты на тренировочной выборке:
#     - `RandomForestRegressor`:
#        -  Лучшие параметры модели:  {'bootstrap': True, 'max_depth': 15, 'min_samples_split': 2, 'n_estimators': 100, 'random_state': 11024}
#        - MAE для тренировочных данных:  `6.22`
#
#     - `CatBoostRegressor`:
#        - Лучшие параметры модели:  {'depth': 5, 'learning_rate': 0.1, 'loss_function': 'MAE', 'n_estimators': 500, 'random_state': 11024}
#        - MAE для тренировочных данных:  `6.11`
#
#     - `LGBMRegressor`:
#         - Лучшие параметры модели:  {'learning_rate': 0.05, 'max_depth': 10, 'metric': 'MAE', 'num_leaves': 10, 'random_state': 11024}
#         - MAE для тренировочных данных:  `6.06`

# %% [markdown]
# ## Выбор лучшей модели

# %% [markdown]
# **Выберите лучшую модель и проверьте её качество на тестовой выборке.**

# %% [markdown]
# Выведем результаты моделей на тренировочной выборке

# %%
models = {'MAE_результат': [model_result, model_result_cbr, model_result_lgbm]}
index_models = ['RandomForestRegressor', 'CatBoostRegressor', 'LGBMRegressor']

df_results = pd.DataFrame(data=models, index=index_models)
pd.set_option('precision', 2)

# %%
df_results.sort_values(by='MAE_результат', ascending=True)
# Out:
#                        MAE_результат
# LGBMRegressor                   6.06
# CatBoostRegressor               6.11
# RandomForestRegressor           6.22

# %% [markdown]
# <div class="alert alert-success" style="border-color: green; border-radius: 5px">
#     <p><u><b>✅ КОММЕНТАРИЙ МЕНТОРА</b></u></p>
#     <p>Всё хорошо.</p>
# </div>👍👍

# %% [markdown]
# Проверим лучшую модель на тестовых данных

# %%
model_for_test_data = LGBMRegressor(
    metric='MAE',
    max_depth=10,
    num_leaves=10,
    learning_rate=0.05,
    random_state=RANDOM_STATE
)

model_for_test_data.fit(X_train, y_train)
predict_model = model_for_test_data.predict(X_test)
result = round(mean_absolute_error(y_test, predict_model), 2)

# %%
print('MAE для тестовых данных: ', result)
# Out:
# MAE для тестовых данных:  6.51

# %% [markdown]
# Посмотрим на важность признаков лучшей модели

# %%
plot_data = {
    'features': X_test.columns,
    'feature_importances': model_for_test_data.feature_importances_
}

plot_data = pd.DataFrame(plot_data)
plot_data.sort_values(by='feature_importances', ascending=False, inplace=True)

# %%
plt.figure(figsize=(20, 10))
sns.barplot(x=plot_data['feature_importances'], y=plot_data['features'])

plt.title('Важность признаков для LGBMRegressor', fontsize=15)
plt.xlabel('Критерий важности')
plt.ylabel('Названия признаков')
plt.show()

# %% [markdown]
# График показывает, что для модели наиболее выжными признаками являются:
#   - `начальная_температура`
#   - `общее_время_нагрева`
#   - `разница_замера`

# %% [markdown]
# <div class="alert alert-success" style="border-color: green; border-radius: 5px">
#     <p><u><b>✅ КОММЕНТАРИЙ МЕНТОРА</b></u></p>хорошо, что используешь этот инструмент. На начальном этапе мы можем нагенерить множество разных фич, в том чтисле и лишних. И вот этот инструмент, вкупе с анализом мультиколлинеарности позволяет избавляться от "балласта"). И этот баллст можно исключить и перестроить модель. Метрика не должна силно измениться.

# %% [markdown]
# **Вывод:**
#
# 1. Лучшая модель на тренировочной выборке является `LGBMRegressor`, так как ее результат `MAE = 6.06`. Данная модель на тестовой выборке показала результат `MAE = 6.51`, что удовлетворяет условию указанные заказчиком, которое должно быть `MAE <= 6.8`.
#
#
# 2. Выявили важность признаков. Для модели наиболее важными признаками стали:
#     - `начальная_температура`
#     - `общее_время_нагрева`
#     - `разница_замера`

# %% [markdown]
# ## Общий вывод и рекомендации заказчику

# %% [markdown]
# 1. Данные корректно загрузили. Проведен первичный осмотр данных, имеется значительное количество пропусков в:
#      - `data_bulk_new.csv`
#      - `data_bulk_time_new.csv`
#      - `data_temp_new.csv`
#      - `data_wire_new.csv`
#      - `data_wire_time_new.csv`
#
#
# 2. Присутствует не соответствие типов данных которые преобразуем из `object` в `datatime`
#
#
# 3. Проведена предобработка данных:
#     - типы данных преобразованы
#     - названия столбцов приведен к "змеинному стилю"
#     - обработаны пропуски в данных
#     - добавлены дополнительные признаки
#     - данные подготовлены к объединению в общий датасет
#
#
# 4. Проведен иследовательский анализ данных. Распределение данных нормальное, в диаграммах размаха видны аномальные значения, которое решено не трогать, чтобы не искажать данные в дальнейших вычислениях.
#
#
# 5. Объедтнили по признаку `key` необходимые датасеты в итоговый:
#     - Пропуски и дубликаты отсутствуют
#     - Убрали ненужные признаки для дальнейшей работы с данными
#
#
# 6. Построили графики всех признаков из нового датасета. В большинстве случаев у нас нормальные распределения признаков, кроме признаков `bulk_3, bulk_4, bulk_15 и wire_2`. В каждом признаке имеются выбросы, которые решили не трогать.
#
#
# 7. Тепловая карта показывает, что существует высокая корелляция признаков между `'активная_мощность', 'реактивная_мощность', 'полная_мощность'`
#
#
# 8. Подготовку двнных выполнили. Затем данные разделили на выборки, которые имеют следующие размеры:
#    - `X_train = (1746, 15)`
#    - `y_train = (1746,)`
#    - `X_test  = (583, 15)`
#    - `y_test  = (583,)`
#
#
# 9. Обучили 3 модели:
#    - `RandomForestRegressor`
#    - `CatBoostRegressor`
#    - `LGBMRegressor`
#
#
# 10. Получили следующие результаты на тренировочной выборке:
#     - `RandomForestRegressor`:
#        -  Лучшие параметры модели:  {'bootstrap': True, 'max_depth': 15, 'min_samples_split': 2, 'n_estimators': 100, 'random_state': 11024}
#        - MAE для тренировочных данных:  `6.22`
#
#     - `CatBoostRegressor`:
#        - Лучшие параметры модели:  {'depth': 5, 'learning_rate': 0.1, 'loss_function': 'MAE', 'n_estimators': 500, 'random_state': 11024}
#        - MAE для тренировочных данных:  `6.11`
#
#     - `LGBMRegressor`:
#         - Лучшие параметры модели:  {'learning_rate': 0.05, 'max_depth': 10, 'metric': 'MAE', 'num_leaves': 10, 'random_state': 11024}
#         - MAE для тренировочных данных:  `6.06`
#
#
# 11. Лучшая модель на тренировочной выборке является `LGBMRegressor`, так как ее результат `MAE = 6.06`. Данная модель на тестовой выборке показала результат `MAE = 6.51`, что удовлетворяет поставленному условию, которое должно быть `MAE <= 6.8`. Выявили важность признаков. Для модели наиболее важными признаками стали:
#     - `начальная_температура`
#     - `общее_время_нагрева`
#     - `разница_замера`

# %% [markdown]
# **Рекомендация:**
# Необходимо уделить внимание точности замеров температурных данных, дать техническое обоснование большому количеству выбросов в данных. Возможно исключить или неиспользовать данные, в которых замеры отсутствуют более 80%. Это может способствовать построению более точной модели с еще более высокими показателями.

# %% [markdown]
# <div class="alert alert-success" style="border-color: green; border-radius: 5px">
#     <p><u><b>✅ КОММЕНТАРИЙ МЕНТОРА</b></u></p>
# ОК, Армен, отличная работа!!! Тут и аналитика, и графика, и рассуждения. При это в меру и достаточно. С уверенностью можно сказать, что пройден весь алгоритм моделирования от анализа исходной инфо до анализа важности факторов.<br>
# В общем-то, вопросов особых и нет) Всё что хотел написать -  тексте оставлял)<br>
#
# Единственное, всегда стараюсь на этом проекте сказать всем вот ещё что: цель заказчика - экономия энергоресурсов.<br>
# И в этом проекте искали как раз способ точно предсказывать температуру. И круто использовали для этого весь арсенал<br>
# А если рассудать с позиции такой: а что нужно сделать, чтобы снизить энергопотребление?<br>
# Судя по модели, самым важным фактором является первая температура. Это значит, что управляя ею, мы сможем управлять энергозатратами. Вывод понятен. Теперь надо разработать мероприятия для этого решения. И тут вопрос возникает скм собой: а это так точно? мы можем управлять первой температурой? В общем, наша модель - только начало работы над энергоэффективностью.<br>
#
# Так же есть ещё одна идея, которую хотел предложить тебе на обсуждение.<br>
# Возможно, покажется интересным<br><br>
#
# Дело касается принципиально иного подхода к поиску решения для снижения энергопотребления на производстве<br>
# Смотри, Создание данной модели (таково было задание) двигалось по пути "угадывания" температуры<br>
# Но мы же знаем жизнь)) лёгкие колебания температур (как и нашего настроения, нашего веса.....)<br>
# есть всегда. Более того - будут вегда! И нам что, стараться угадывать их?<br>
# Не угонимся, "пупок" развяжется))))) <br>
# Предложу для подобных проектов подумать вот в какую сторону<br>
#
# Итак, разброс в измерениях - есть, был и будет!! (т.к. этому благоприятствует разнообразие факторов самого проиозводства)<br>
#     Тогда задачу можно поставить так: <u>надо уменьшить разброс в измерениях</u>. В данном случае в температуре.<br>
# Один из подходов такой: Наверняка есть границы, в пределах которых колебания температур - дело нормальное.<br>
# А что, если фикировать случаи, когда температура выходит за эти границы?<br>
# Скажем, как "1". И тогда для таких моментов времени собирать инфо по производству: <br>
# а что был за материал (химия материала), что был за газ (химический состав газа), какая бригада работала, <br>
# что там было с электродами, ограничения только в фантазиях ну и в знаниях самого производства..... <br>
# И вот тут можем реально находить причины (через корреляции, проверки гипотез, разные модельки...), фиксировать эти причины. <br>
# Ну и разрабатывать энергосберегательные мероприятия.<br><br>
#
# Это было отступление)<br>
# Как и писал - вопросов нет, может у тебя остались/появились? <br>
# БУДУ ЖДАТЬ! <br>

# %% [markdown]
# <div style="background: #B0E0E6; padding: 5px; border: 1px solid SteelBlue; border-radius: 5px;">
#     <font color='4682B4'><u><b>КОММЕНТАРИЙ СТУДЕНТА</b></u></font>
#     <br />
#     <font color='4682B4'>Добрый вечер, Николай! Большое спасибо за проделанную проверку моего проекта. Вопросов в данный момент нет, ты все подробно объяснил и разъяснил на онлайн встрече, которую я смог послушать в записи, так как не получилось присутствовать на встрече. Еще раз большое спасибо!</font>
# </div>

# %% [markdown]
# <div class="alert alert-success" style="border-color: green; border-radius: 5px">
#     <p><u><b>✅ КОММЕНТАРИЙ МЕНТОРА 2</b></u></p>
# Доброго дня, Армен. Спасибо за отклик!!<br>
#
# Далее на  правах ментора скажу, что стараюсь говорить всем на финале.<br>
# Пройден большой путь. Со своими коcогорами и равнинами, медианами и дисперсиями)<br>
# Умение аналитически мыслить, писать красивый код, эффективно автоматизировать расчёты, видеть задачи бизнеса через призму моделирования - вот то основное, что  останется у тебя важного после нашей школы. А дальше - только взращивать посеянные зёрна и укреплять свои скилы.<br><br>
# Если говорить о развитии дополнительных компетенций, рекомендовал бы ещё глянуть такие области знаний:<br>
# 1) Организация проектов по проведению моделирования (например Методология CRISP-DM (Cross-Industry Standard Process)<br>
# 2) Умения системно подходить к решению аналитической задачи. (например методология ТРИЗ, системный анализ)<br>
# 3) Если в промышленности будут проекты, то рекоммендовал бы освоить  "Статистичекий контроль качества (SPC)"<br>
# 4) Ещё важный навык: перевод результататов моделирования на язык бизнеса. Т.е. понимание, как целевые показатели моделей влияют на финансовую выгоду заказчика.<br>
#
# Каждого из нас (и меня в том числе) можно оценивать с нескольких сторон, как специалиста.<br>
# 1) Умение анализировать, "вгрызание" в данные, в задачу.<br>
# 2) Знание мат.части: методы, подходы к решению - всё, что по программе заложено<br>
# 3) Кодовая часть: умение писать эффективный код.<br>
# 4) Работа с графикой. (умение хорошо ыизуализировать)<br>
# И при рабочей деятельности (устраивание на работу/ улучшение карьеры) на важно понимать свои слабые/сильные стороны по этим направлениям. И опираться на них при ведении переговоров и выстраивании дальнейшего совершенствования.<br><br>
#
# Спасибо за этот труд!<br>
# Искренне желаю покорить ещё не один аналитический Эверест)<br>
